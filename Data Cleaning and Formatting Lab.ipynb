# %% [markdown]
# # Lab | Data Cleaning and Formatting

# %% [markdown]
# In this lab, we will be working with the customer data from an insurance company, which can be found in the CSV file located at the following link: https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv

# %% [markdown]
# # Challenge 1: Data Cleaning and Formatting

# %% [markdown]
# ## Exercise 1: Cleaning Column Names

# %% [markdown]
# To ensure consistency and ease of use, standardize the column names of the dataframe. Start by taking a first look at the dataframe and identifying any column names that need to be modified. Use appropriate naming conventions and make sure that column names are descriptive and informative.
#
# *Hint*:
# - *Column names should be in lower case*
# - *White spaces in column names should be replaced by `_`*
# - *`st` could be replaced for `state`*

# %%
# Your code here
import pandas as pd
insurance_data = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv')
insurance_data
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
insurance_data.rename(str.lower, axis='columns', inplace=True)

# %%
insurance_data.rename(columns={'customer': 'customer id'}, inplace=True)

# %%
insurance_data.rename(columns = lambda x: x.replace(' ', '_'), inplace=True)
insurance_data
# Out:
#      customer_id          st gender             education  \
# 0        RB50392  Washington    NaN                Master
# 1        QZ44356     Arizona      F              Bachelor
# 2        AI49188      Nevada      F              Bachelor
# 3        WW63253  California      M              Bachelor
# 4        GA49547  Washington      M  High School or Below
# ...          ...         ...    ...                   ...
# 4003         NaN         NaN    NaN                   NaN
# 4004         NaN         NaN    NaN                   NaN
# 4005         NaN         NaN    NaN                   NaN
# 4006         NaN         NaN    NaN                   NaN
# 4007         NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# ## Exercise 2: Cleaning invalid Values

# %% [markdown]
# The dataset contains columns with inconsistent and incorrect values that could affect the accuracy of our analysis. Therefore, we need to clean these columns to ensure that they contain only valid data.
#
# Note that this exercise will focus only on cleaning inconsistent values and will not involve handling null values (NaN or None).
#
# *Hint*:
# - *Gender column contains various inconsistent values such as "F", "M", "Femal", "Male", "female", which need to be standardized, for example, to "M" and "F".*
# - *State abbreviations can replaced with its full name, for example "AZ": "Arizona", "Cali": "California", "WA": "Washington"*
# - *In education, "Bachelors" could be replaced by "Bachelor"*
# - *In Customer Lifetime Value, delete the `%` character*
# - *In vehicle class, "Sports Car", "Luxury SUV" and "Luxury Car" could be replaced by "Luxury"*

# %%
# Your code here
insurance_data.value_counts('gender')
# Out:
# gender
# F         457
# M         413
# Male       39
# female     28
# Femal      17
# Name: count, dtype: int64

# %%
insurance_data.replace('Male', 'M', inplace=True)

# %%
insurance_data.replace(['female', 'Femal'], 'F', inplace=True)

# %%
insurance_data.value_counts('st')
# Out:
# st
# Oregon        320
# California    211
# Arizona       186
# Cali          120
# Nevada         98
# Washington     81
# WA             30
# AZ             25
# Name: count, dtype: int64

# %%
insurance_data.replace('Cali', 'California', inplace=True)

# %%
insurance_data.replace('WA', 'Washington', inplace=True)

# %%
insurance_data.replace('AZ', 'Arizona', inplace=True)

# %%
insurance_data.value_counts('education')
# Out:
# education
# Bachelor                324
# College                 313
# High School or Below    296
# Master                   94
# Doctor                   37
# Bachelors                 7
# Name: count, dtype: int64

# %%
insurance_data.replace('Bachelors', 'Bachelor', inplace=True)

# %%
insurance_data['customer_lifetime_value'] = insurance_data['customer_lifetime_value'].str.replace('%', '')

# %%
insurance_data.value_counts('vehicle_class')
# Out:
# vehicle_class
# Four-Door Car    576
# Two-Door Car     205
# SUV              199
# Sports Car        57
# Luxury SUV        20
# Luxury Car        14
# Name: count, dtype: int64

# %%
insurance_data.replace(['Sports Car', 'Luxury SUV', 'Luxury Car'], 'Luxury', inplace=True)

# %% [markdown]
# ## Exercise 3: Formatting data types

# %% [markdown]
# The data types of many columns in the dataset appear to be incorrect. This could impact the accuracy of our analysis. To ensure accurate analysis, we need to correct the data types of these columns. Please update the data types of the columns as appropriate.

# %% [markdown]
# It is important to note that this exercise does not involve handling null values (NaN or None).

# %% [markdown]
# *Hint*:
# - *Customer lifetime value should be numeric*
# - *Number of open complaints has a wrong format, look at the diffrent values it takes with unique() and take the middle value, for example 1/5/00 should be 5. Number of open complaints is a string, remember you can use split() to deal with it and take the number you need. Finally, since it should be numeric, cast the column to be in its proper type.*

# %%
# Your code here
insurance_data['customer_lifetime_value'] = insurance_data['customer_lifetime_value'].astype(float)

# %%
insurance_data['number_of_open_complaints'] = insurance_data['number_of_open_complaints'].astype(str)

# %%
insurance_data[['nothing', 'number_of_open_complaints', 'ignore']] = insurance_data['number_of_open_complaints'].str.split('/', expand=True)

# %%
insurance_data.drop(columns=['nothing', 'ignore'], inplace=True)

# %%
insurance_data['number_of_open_complaints'] = insurance_data['number_of_open_complaints'].astype(float)

# %%
insurance_data
# Out:
#      customer_id          st gender             education  \
# 0        RB50392  Washington    NaN                Master
# 1        QZ44356     Arizona      F              Bachelor
# 2        AI49188      Nevada      F              Bachelor
# 3        WW63253  California      M              Bachelor
# 4        GA49547  Washington      M  High School or Below
# ...          ...         ...    ...                   ...
# 4003         NaN         NaN    NaN                   NaN
# 4004         NaN         NaN    NaN                   NaN
# 4005         NaN         NaN    NaN                   NaN
# 4006         NaN         NaN    NaN                   NaN
# 4007         NaN         NaN    NaN                   NaN
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# ...

# %% [markdown]
# ## Exercise 4: Dealing with Null values

# %% [markdown]
# Identify any columns with null or missing values. Identify how many null values each column has. You can use the isnull() function in pandas to find columns with null values.
#
# Decide on a strategy for handling the null values. There are several options, including:
#
# - Drop the rows or columns with null values
# - Fill the null values with a specific value (such as the column mean or median for numerical variables and mode for categorical variables)
# - Fill the null values with the previous or next value in the column
# - Fill the null values based on a more complex algorithm or model (we haven't studied this yet)
#
# Implement your chosen strategy to handle the null values. You can use the fillna() function in pandas to fill null values or dropna() function to drop null values.
#
# Verify that your strategy has successfully handled the null values. You can use the isnull() function again to check if there are still null values in the dataset.
#
# Remember to document your process and explain your reasoning for choosing a particular strategy for handling null values.
#
# After formatting data types, as a last step, convert all the numeric variables to integers using applymap.

# %%
#dropped all empty rows

insurance_data.dropna(how='all', inplace=True)
insurance_data
# Out:
#      customer_id          st gender             education  \
# 0        RB50392  Washington    NaN                Master
# 1        QZ44356     Arizona      F              Bachelor
# 2        AI49188      Nevada      F              Bachelor
# 3        WW63253  California      M              Bachelor
# 4        GA49547  Washington      M  High School or Below
# ...          ...         ...    ...                   ...
# 1066     TM65736      Oregon      M                Master
# 1067     VJ51327  California      F  High School or Below
# 1068     GS98873     Arizona      F              Bachelor
# 1069     CW49887  California      F                Master
# 1070     MY31220  California      F               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# ...

# %%
# Your code here
# gender is missing from 10% of rows
insurance_data['gender'].isna().value_counts()
# Out:
# gender
# False    954
# True     117
# Name: count, dtype: int64

# %%
insurance_data.loc[insurance_data['income'] == 0]
# Out:
#      customer_id          st gender             education  \
# 0        RB50392  Washington    NaN                Master
# 1        QZ44356     Arizona      F              Bachelor
# 3        WW63253  California      M              Bachelor
# 7        CF85061     Arizona      M                Master
# 10       SX51350  California      M               College
# ...          ...         ...    ...                   ...
# 1046     RG30482      Oregon      F               College
# 1048     QQ39596     Arizona      F               College
# 1055     KJ86296      Oregon      M  High School or Below
# 1058     UX92071      Oregon      M  High School or Below
# 1061     RY92647  California      F              Bachelor
#
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                         NaN     0.0                1000.0
# 1                   697953.59     0.0                  94.0
# 3                   764586.18     0.0                 106.0
# ...

# %%
bachelors = insurance_data.loc[insurance_data['education'] == 'Bachelor']

# %%
# created separate list for those with a bachelor's degree, removed rows with income of 0

bachelors = bachelors[bachelors.income != 0]
bachelors
# Out:
#      customer_id          st gender education  customer_lifetime_value  \
# 2        AI49188      Nevada      F  Bachelor               1288743.17
# 5        OC83172      Oregon      F  Bachelor                825629.78
# 8        DY87989      Oregon      M  Bachelor               2412750.40
# 15       BW63560      Oregon    NaN  Bachelor                746313.94
# 21       QK46697  Washington      M  Bachelor                617710.93
# ...          ...         ...    ...       ...                      ...
# 1054     RJ85627  Washington      F  Bachelor               1230276.24
# 1056     PI47776      Oregon      F  Bachelor                253070.51
# 1064     YT69858  Washington      F  Bachelor                544142.01
# 1065     XD85577  California      M  Bachelor                284226.69
# 1068     GS98873     Arizona      F  Bachelor                323912.47
#
#        income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
#found median income of those with reported income and bachelors degree

bachelors.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count             2.600000e+02    260.000000            260.000000
# mean              8.025875e+05  51269.465385            143.342308
# std               6.655851e+05  24635.229899            561.619825
# min               2.248450e+05  10269.000000             61.000000
# 25%               3.930123e+05  29688.500000             67.000000
# 50%               5.968836e+05  48518.000000             76.000000
# 75%               9.045889e+05  70540.000000            107.250000
# max               5.816655e+06  99934.000000           6464.000000
#
#        number_of_open_complaints  total_claim_amount
# count                 260.000000          260.000000
# mean                    0.380769          348.674717
# std                     0.841271          293.372347
# min                     0.000000            0.382107
# 25%                     0.000000          133.026334
# ...

# %%
insurance_data.loc[(insurance_data['education'] == 'Bachelor') & (insurance_data['income'] == 0), 'income'] = 48518

# %%
masters = insurance_data.loc[insurance_data['education'] == 'Master']

# %%
masters = masters[masters.income != 0]
masters
# Out:
#      customer_id          st gender education  customer_lifetime_value  \
# 12       DP39365  California    NaN    Master                879879.70
# 29       EJ77678      Oregon    NaN    Master                323536.05
# 37       DM79012      Oregon    NaN    Master                738097.67
# 53       NW21079  Washington      F    Master                487938.48
# 59       UB61619      Oregon    NaN    Master                405956.74
# ...          ...         ...    ...       ...                      ...
# 990      ON77827     Arizona      F    Master                279022.80
# 996      PV55726      Oregon      F    Master                417068.73
# 1035     BU41599  Washington      F    Master                558176.13
# 1066     TM65736      Oregon      M    Master                305955.03
# 1069     CW49887  California      F    Master                462680.11
#
#        income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
masters.describe()
# Out:
#        customer_lifetime_value       income  monthly_premium_auto  \
# count             8.800000e+01     89.00000             89.000000
# mean              7.397083e+05  54263.94382            160.887640
# std               6.270881e+05  24089.90716            676.258464
# min               2.451753e+05  11621.00000             61.000000
# 25%               3.655828e+05  34990.00000             68.000000
# 50%               5.588798e+05  50335.00000             80.000000
# 75%               8.614177e+05  75690.00000            109.000000
# max               4.022401e+06  99960.00000           6464.000000
#
#        number_of_open_complaints  total_claim_amount
# count                  89.000000           89.000000
# mean                    0.382022          261.297296
# std                     0.682669          179.373753
# min                     0.000000            5.434505
# 25%                     0.000000          118.454974
# ...

# %%
insurance_data.loc[(insurance_data['education'] == 'Master') & (insurance_data['income'] == 0), 'income'] = 50335

# %%
colleges = insurance_data.loc[insurance_data['education'] == 'College']

# %%
colleges = colleges[colleges.income != 0]
colleges
# Out:
#      customer_id          st gender education  customer_lifetime_value  \
# 6        XZ87318      Oregon      F   College                538089.86
# 9        BQ94931      Oregon      F   College                738817.81
# 14       IL66569  California    NaN   College                538443.17
# 17       OE15005  California    NaN   College                394524.16
# 18       WC83389      Oregon    NaN   College                571033.31
# ...          ...         ...    ...       ...                      ...
# 1057     MD73554  California      M   College                525198.40
# 1059     YG44474      Oregon      M   College               1401472.13
# 1060     UH45301      Oregon      M   College                943891.56
# 1063     GQ66762  California      M   College                477368.64
# 1070     MY31220  California      F   College                899704.02
#
#        income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
colleges.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count             2.350000e+02    235.000000            235.000000
# mean              8.568645e+05  51348.608511            270.187234
# std               7.211256e+05  24377.439934           2335.865503
# min               2.357747e+05  10621.000000             61.000000
# 25%               4.410126e+05  28142.000000             69.000000
# 50%               6.262663e+05  50631.000000             80.000000
# 75%               9.684728e+05  68003.000000            110.500000
# max               4.479547e+06  99790.000000          35353.000000
#
#        number_of_open_complaints  total_claim_amount
# count                 235.000000          235.000000
# mean                    0.412766          371.853635
# std                     0.940453          260.169483
# min                     0.000000            1.838367
# 25%                     0.000000          183.175185
# ...

# %%
insurance_data.loc[(insurance_data['education'] == 'College') & (insurance_data['income'] == 0), 'income'] = 50631

# %%
highschools = insurance_data.loc[insurance_data['education'] == 'High School or Below']

# %%
highschools = highschools[highschools.income != 0]
highschools
# Out:
#      customer_id          st gender             education  \
# 4        GA49547  Washington      M  High School or Below
# 13       SJ95423     Arizona    NaN  High School or Below
# 16       FV94802      Nevada    NaN  High School or Below
# 19       FL50705  California    NaN  High School or Below
# 20       ZK25313      Oregon    NaN  High School or Below
# ...          ...         ...    ...                   ...
# 1049     FH51383  California      F  High School or Below
# 1050     BJ53923     Arizona      M  High School or Below
# 1052     FB23788      Oregon      M  High School or Below
# 1062     IK12620     Arizona      F  High School or Below
# 1067     VJ51327  California      F  High School or Below
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 4                   536307.65  36357.0                  68.0
# 13                  881901.89  99845.0                 110.0
# 16                  256686.78  25049.0                  67.0
# ...

# %%
highschools.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count             2.030000e+02    204.000000            204.000000
# mean              8.090023e+05  50365.279412             93.509804
# std               6.385531e+05  24164.986693             33.827509
# min               2.227073e+05  10312.000000             61.000000
# 25%               4.221622e+05  27972.000000             68.000000
# 50%               5.744230e+05  50283.000000             88.000000
# 75%               9.065545e+05  70363.750000            108.000000
# max               3.585060e+06  99845.000000            276.000000
#
#        number_of_open_complaints  total_claim_amount
# count                 204.000000          204.000000
# mean                    0.348039          382.424778
# std                     0.801136          261.285626
# min                     0.000000            1.924709
# 25%                     0.000000          201.732691
# ...

# %%
insurance_data.loc[(insurance_data['education'] == 'High School or Below') & (insurance_data['income'] == 0), 'income'] = 50283

# %%
doctors = insurance_data.loc[insurance_data['education'] == 'Doctor']

# %%
doctors = doctors[doctors.income != 0]
doctors
# Out:
#      customer_id          st gender education  customer_lifetime_value  \
# 44       YD87931  Washington      M    Doctor                495165.61
# 45       HG65722      Oregon    NaN    Doctor               1281910.29
# 82       DT85712  California    NaN    Doctor                411853.91
# 143      FF22360  Washington      F    Doctor                268731.41
# 163      GK92563  Washington      F    Doctor                681923.12
# 171      LP45550      Oregon      F    Doctor               1536384.72
# 176      GX84338  Washington      F    Doctor                382443.13
# 252      PK52952     Arizona      M    Doctor                854441.11
# 295      WV76014     Arizona      M    Doctor                254040.77
# 313      DE34457      Oregon      F    Doctor                941690.85
# 321      EN61670     Arizona      F    Doctor                533246.27
# 347      NM39588  Washington      F    Doctor                267805.83
# ...

# %%
doctors.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count             3.100000e+01     31.000000             31.000000
# mean              6.904109e+05  51119.483871           1232.870968
# std               4.761800e+05  24295.177705           6332.755281
# min               2.491317e+05  10105.000000             61.000000
# 25%               3.468294e+05  29520.500000             69.000000
# 50%               5.332463e+05  55411.000000             88.000000
# 75%               8.817006e+05  70329.500000            105.000000
# max               2.017196e+06  89398.000000          35354.000000
#
#        number_of_open_complaints  total_claim_amount
# count                  31.000000           31.000000
# mean                    0.419355          227.574308
# std                     0.958269          179.878399
# min                     0.000000            0.517753
# 25%                     0.000000           74.970413
# ...

# %%
insurance_data.loc[(insurance_data['education'] == 'Doctor') & (insurance_data['income'] == 0), 'income'] = 55411

# %%
# Back filled gender because my last row had a gender and my first did not :)

insurance_data['gender'].bfill(inplace=True)

# %%
# for few remaining NaNs, deleted entire row

insurance_data.dropna(inplace=True)

# %%
insurance_data.isnull()
# Out:
#       customer_id     st  gender  education  customer_lifetime_value  income  \
# 1           False  False   False      False                    False   False
# 2           False  False   False      False                    False   False
# 3           False  False   False      False                    False   False
# 4           False  False   False      False                    False   False
# 5           False  False   False      False                    False   False
# ...           ...    ...     ...        ...                      ...     ...
# 1066        False  False   False      False                    False   False
# 1067        False  False   False      False                    False   False
# 1068        False  False   False      False                    False   False
# 1069        False  False   False      False                    False   False
# 1070        False  False   False      False                    False   False
#
# ...

# %%
numeric_columns = ['customer_lifetime_value', 'income', 'monthly_premium_auto', 'number_of_open_complaints', 'total_claim_amount']

# %%
insurance_data[numeric_columns] = insurance_data[numeric_columns].applymap(lambda x: float(x))

# %%
insurance_data
# Out:
#      customer_id          st gender             education  \
# 1        QZ44356     Arizona      F              Bachelor
# 2        AI49188      Nevada      F              Bachelor
# 3        WW63253  California      M              Bachelor
# 4        GA49547  Washington      M  High School or Below
# 5        OC83172      Oregon      F              Bachelor
# ...          ...         ...    ...                   ...
# 1066     TM65736      Oregon      M                Master
# 1067     VJ51327  California      F  High School or Below
# 1068     GS98873     Arizona      F              Bachelor
# 1069     CW49887  California      F                Master
# 1070     MY31220  California      F               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 1                   697953.59  48518.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# 3                   764586.18  48518.0                 106.0
# ...

# %% [markdown]
# ## Exercise 5: Dealing with duplicates

# %% [markdown]
# Use the .duplicated() method to identify any duplicate rows in the dataframe.
#
# Decide on a strategy for handling the duplicates. Options include:
# - Dropping all duplicate rows
# - Keeping only the first occurrence of each duplicated row
# - Keeping only the last occurrence of each duplicated row
# - Dropping duplicates based on a subset of columns
# - Dropping duplicates based on a specific column
#
# Implement your chosen strategy using the drop_duplicates() function.
#
# Verify that your strategy has successfully handled the duplicates by checking for duplicates again using .duplicated().
#
# Remember to document your process and explain your reasoning for choosing a particular strategy for handling duplicates.
#
# Save the cleaned dataset to a new CSV file.
#
# *Hint*: *after dropping duplicates, reset the index to ensure consistency*.

# %%
# Your code here
# Found no duplicated rows

insurance_data.duplicated().value_counts()
# Out:
# False    1068
# Name: count, dtype: int64

# %%
insurance_data.to_csv('cleaned_insurance_data.csv')

# %% [markdown]
# # Bonus: Challenge 2: creating functions on a separate `py` file

# %% [markdown]
# Put all the data cleaning and formatting steps into functions, and create a main function that performs all the cleaning and formatting.
#
# Write these functions in a separate .py file(s). By putting these steps into functions, we can make the code more modular and easier to maintain.

# %% [markdown]
# *Hint: autoreload module is a utility module in Python that allows you to automatically reload modules in the current session when changes are made to the source code. This can be useful in situations where you are actively developing code and want to see the effects of changes you make without having to constantly restart the Python interpreter or Jupyter Notebook kernel.*

# %%
# Your code here

# %% [markdown]
# # Bonus: Challenge 3: Analyzing Clean and Formated Data

# %% [markdown]
# You have been tasked with analyzing the data to identify potential areas for improving customer retention and profitability. Your goal is to identify customers with a high policy claim amount and a low customer lifetime value.
#
# In Pandas Lab, we only looked at high policy claim amounts because we couldn't look into low customer lifetime values. If we tried to do work with that column, we wouldn't have been able to do it because customer lifetime value wasn't clean and in its proper format. So after cleaning and formatting the data, lets get some more interesting insights!
#
# Instructions:
#
# - Review again the statistics for total claim amount and customer lifetime value to gain an understanding of the data.
# - To identify potential areas for improving customer retention and profitability, we want to focus on customers with a high policy claim amount and a low customer lifetime value. Consider customers with a high policy claim amount to be those in the top 25% of the total claim amount, and clients with a low customer lifetime value to be those in the bottom 25% of the customer lifetime value. Create a pandas DataFrame object that contains information about customers with a policy claim amount greater than the 75th percentile and a customer lifetime value in the bottom 25th percentile.
# - Use DataFrame methods to calculate summary statistics about the high policy claim amount and low customer lifetime value data. To do so, select both columns of the dataframe simultaneously and pass it to the .describe() method. This will give you descriptive statistics, such as mean, median, standard deviation, minimum and maximum values for both columns at the same time, allowing you to compare and analyze their characteristics.

# %%
# Your code here
